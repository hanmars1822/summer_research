# %%
# %pylab inline
from astropy.io import fits
import glob
import pandas as pd
from scipy.interpolate import interp1d
from nirspec import divspec, gluespec
import pdb as pdb
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# First step: Look at google sheet and identify sets of adjacent dates on which source was observed.  Each set of dates will have its own reduction.
#
# https://docs.google.com/spreadsheets/d/132AukRxC_ed6i_5SCwBAB5wLHYxvxrCHrTXb4KEQdjs/edit#gid=53493886

# %% [markdown]
# ## 20101213, 20101214, 201101215

# %% [markdown]
# For this set of dates, use the code below to investigate each date.
#
# -First see if source was observed on that date
#
# -Then, identify the best standard-star observations for the source.  These observations should be of a standard star (usually beginning with "HR"), be in the same setting as the source, be on the same night as the source, and be at a close airmass to the source (or the closest you can find).
#
# -Once you've identified the best standard-star observations for the source, add the file names to the Time_domain_log google sheet.  *One important note:*  The files "ABAUR_20101213_1156_spec1d1.fits" and "ABAUR_20101213_1156_spec1d2.fits" represent the same grating setting, but different spectral orders (different wavelengths).  Therefore, the standard star files must have the same ending to match (i.e., d1.fits or d2.fits, as needed).

# %%
datadir='/Users/csalyk/Dropbox/NIRSPEC_timedomain/data/'
filelist=glob.glob(datadir+'*20101214*.fits')
for i,file in enumerate(filelist):
    filename=(file.split('/'))[-1]
    hdulist=fits.open(file)
    print(filename,hdulist[0].header['AIRMASS'],hdulist[0].header['FILNAME'],hdulist[0].header['WAVA_POS'])
# Out:
# ABAUR_20101214_1032_spec1d1.fits 1.03489 M-WIDE-AO 4.711393
# ABAUR_20101214_1032_spec1d2.fits 1.03489 M-WIDE-AO 5.023287
# ABAUR_20101214_1057_spec1d1.fits 1.05918 M-WIDE-AO 4.711393
# ABAUR_20101214_1057_spec1d2.fits 1.05918 M-WIDE-AO 5.023287
# HD50138_20101214_1331_spec1d1.fits 1.26791 M-WIDE-AO 4.711393
# HD50138_20101214_1331_spec1d2.fits 1.26791 M-WIDE-AO 5.023287
# HD50138_20101214_1350_spec1d1.fits 1.33451 M-WIDE-AO 4.711393
# HD50138_20101214_1350_spec1d2.fits 1.33451 M-WIDE-AO 5.023287
# HR1620_20101214_0900_spec1d1.fits 1.02489 M-WIDE-AO 4.711393
# HR1620_20101214_0900_spec1d2.fits 1.02489 M-WIDE-AO 5.023287
# HR1620_20101214_1236_spec1d1.fits 1.2675 M-WIDE-AO 4.711393
# HR1620_20101214_1236_spec1d2.fits 1.2675 M-WIDE-AO 5.023287
# HR383_20101214_0459_spec1d1.fits 1.05036 M-WIDE-AO 4.711393
# HR383_20101214_0459_spec1d2.fits 1.05036 M-WIDE-AO 5.023287
# HR4494_20101214_1607_spec1d1.fits 1.73261 M-WIDE-AO 4.711393
# ...

# %% [markdown]
# Now, for each source input file, run divspec with the appropriate source and standard files. Comment out the codes for other files, so you only look at one reduction at a time.
#
# For each pair of files, you'll need to adjust "dtau" (which accounts for differences in the atmospheric optical depth) and "dpix" (which accounts for small offsets in wavelength between source and standard).  You will also need to choose the right mode for the wavelength observed.
#
# 'M1' = 4.711393
# 'M3' = 5.023287
#
# 'M2' = 4.646994
# 'M4' = 4.954114
#
# How do you choose the right dtau and dpix?  Try small shifts to see visually whether the make the final divided spectrum less noisy.  Also, look at the signal-to-noise ratio (SNR) values.  The green dashed vertica lines show where the SNR's are being measured.

# %%
#20101214
srcfile='LkHa330_20101214_0638_spec1d1.fits'
stdfile='HR383_20101214_0459_spec1d1.fits'
#out=divspec(datadir, srcfile, stdfile, dtau=0.04, dpix=-0.4, mode='M1')

srcfile='LkHa330_20101214_0638_spec1d2.fits'
stdfile='HR383_20101214_0459_spec1d2.fits'
#out=divspec(datadir, srcfile, stdfile, dtau=0.04, dpix=-0.4, mode='M3')

srcfile='LkHa330_20101214_0709_spec1d1.fits'
stdfile='HR383_20101214_0459_spec1d1.fits'
#out=divspec(datadir, srcfile, stdfile, dtau=0.01, dpix=-0.3, mode='M1')

srcfile='LkHa330_20101214_0709_spec1d2.fits'
stdfile='HR383_20101214_0459_spec1d2.fits'
#out=divspec(datadir, srcfile, stdfile, dtau=0.01, dpix=-0.4, mode='M3')

srcfile='LkHa330_20101214_0738_spec1d1.fits'
stdfile='HR383_20101214_0459_spec1d1.fits'
#out=divspec(datadir, srcfile, stdfile, dtau=-0.02, dpix=-0.1, mode='M1')

srcfile='LkHa330_20101214_0738_spec1d2.fits'
stdfile='HR383_20101214_0459_spec1d2.fits'
#out=divspec(datadir, srcfile, stdfile, dtau=-0.02, dpix=-0.2, mode='M3')

srcfile='LkHa330_20101214_0820_spec1d1.fits'
stdfile='HR383_20101214_0459_spec1d1.fits'
#out=divspec(datadir, srcfile, stdfile, dtau=0.01, dpix=-0.3, mode='M1')

srcfile='LkHa330_20101214_0820_spec1d2.fits'
stdfile='HR383_20101214_0459_spec1d2.fits'
#out=divspec(datadir, srcfile, stdfile, dtau=0.07, dpix=-0.3, mode='M3')

#20101215
srcfile='LkHa330_20101215_0454_spec1d1.fits'
stdfile='HR1620_20101215_1331_spec1d1.fits'
#out=divspec(datadir, srcfile, stdfile, dtau=-0.08, dpix=-0.4, mode='M1')

srcfile='LkHa330_20101215_0454_spec1d2.fits'
stdfile='HR1620_20101215_1331_spec1d2.fits'
#out=divspec(datadir, srcfile, stdfile, dtau=-0.06, dpix=-0.4, mode='M3')

srcfile='LkHa330_20101215_0524_spec1d1.fits'
stdfile='HR936_20101215_0442_spec1d1.fits'
#out=divspec(datadir, srcfile, stdfile, dtau=-0.07, dpix=0.2, mode='M1')

srcfile='LkHa330_20101215_0524_spec1d2.fits'
stdfile='HR936_20101215_0442_spec1d2.fits'
#out=divspec(datadir, srcfile, stdfile, dtau=-0.05, dpix=0.2, mode='M3')
# Out:
# SNR: 23.57036575463531 19.412464139431812 6.393431974824382
# Writing to:  LkHa330_HR383_20101214_0638_M1_div.fits
# SNR: 45.72780745770502 37.00726355738126 41.82577444550715
# Writing to:  LkHa330_HR383_20101214_0638_M3_div.fits
# SNR: 23.327688340980526 21.932607267780593 10.965967113880552
# Writing to:  LkHa330_HR383_20101214_0709_M1_div.fits
# SNR: 58.74482432204047 49.913264010682084 71.09144904159427
# Writing to:  LkHa330_HR383_20101214_0709_M3_div.fits
# SNR: 24.25728585162418 21.97943515429208 17.79063528611354
# Writing to:  LkHa330_HR383_20101214_0738_M1_div.fits
# SNR: 57.08411441280539 57.20028072757053 53.01211868460522
# Writing to:  LkHa330_HR383_20101214_0738_M3_div.fits
# SNR: 20.16121593048603 17.80498911290373 8.18179517523572
# Writing to:  LkHa330_HR383_20101214_0820_M1_div.fits
# SNR: 46.275556281870266 49.3364301068277 42.5683612081035
# Writing to:  LkHa330_HR383_20101214_0820_M3_div.fits
# SNR: 22.333382128594007 19.67870541485765 10.863134909230455
# ...

# %% [markdown]
# ## 20110620

# %% [markdown]
# ## 20120512, 20120513

# %% [markdown]
# ## 20120701, 20120702

# %% [markdown]
# ## 20121022

# %%
datadir='/Users/csalyk/Dropbox/NIRSPEC_timedomain/data/'
filelist=glob.glob(datadir+'*20121022*.fits')
for i,file in enumerate(filelist):
    filename=(file.split('/'))[-1]
    hdulist=fits.open(file)
    print(filename,hdulist[0].header['AIRMASS'],hdulist[0].header['FILNAME'],hdulist[0].header['WAVA_POS'])
# Out:
# DOTAU_20121022_1050_spec1d1.fits 1.14815 M-WIDE-AO 4.646994
# DOTAU_20121022_1050_spec1d2.fits 1.14815 M-WIDE-AO 4.954114
# DOTAU_20121022_1058_spec1d1.fits 1.12828 M-WIDE-AO 4.646994
# DOTAU_20121022_1058_spec1d2.fits 1.12828 M-WIDE-AO 4.954114
# DOTAU_20121022_1139_spec1d1.fits 1.05458 M-WIDE-AO 4.646994
# DOTAU_20121022_1139_spec1d2.fits 1.05458 M-WIDE-AO 4.954114
# DOTAU_20121022_1321_spec1d1.fits 1.01168 M-WIDE-AO 4.646994
# DOTAU_20121022_1321_spec1d2.fits 1.01168 M-WIDE-AO 4.954114
# DOTAU_20121022_1355_spec1d1.fits 1.03572 M-WIDE-AO 4.646994
# DOTAU_20121022_1355_spec1d2.fits 1.03572 M-WIDE-AO 4.954114
# HR1620_20121022_1229_spec1d1.fits 1.02252 M-WIDE-AO 4.646994
# HR1620_20121022_1229_spec1d2.fits 1.02252 M-WIDE-AO 4.954114
# HR1620_20121022_1507_spec1d1.fits 1.10448 M-WIDE-AO 4.646994
# HR1620_20121022_1507_spec1d2.fits 1.10448 M-WIDE-AO 4.954114
# HR936_20121022_1036_spec1d1.fits 1.0912 M-WIDE-AO 4.646994
# HR936_20121022_1036_spec1d2.fits 1.0912 M-WIDE-AO 4.954114
# ...

# %%
#20121022
srcfile='LkHa330_20121022_0903_spec1d1.fits'
stdfile='HR1620_20121022_1507_spec1d1.fits'
#out=divspec(datadir, srcfile, stdfile, dtau=0.08, dpix=0.3,mode='M0')

srcfile='LkHa330_20121022_0903_spec1d2.fits'
stdfile='HR1620_20121022_1507_spec1d2.fits'
#out=divspec(datadir, srcfile, stdfile, dtau=0.08, dpix=0.3, mode='M2')

srcfile='LkHa330_20121022_0953_spec1d1.fits'
stdfile='HR1620_20121022_1507_spec1d1.fits'
#out=divspec(datadir, srcfile, stdfile, dtau=0.0, dpix=0.3, mode='M0')

srcfile='LkHa330_20121022_0953_spec1d2.fits'
stdfile='HR1620_20121022_1507_spec1d2.fits'
#out=divspec(datadir, srcfile, stdfile, dtau=0.0, dpix=0.3, mode='M2')
# Out:
# SNR: 43.566063903901096 55.4505367129093 25.391247982025398
# Writing to:  LkHa330_HR1620_20121022_0903_M0_div.fits
# SNR: 35.220860269889016 31.476115270250247 38.39105792848828
# Writing to:  LkHa330_HR1620_20121022_0903_M2_div.fits
# SNR: 52.4518713166224 65.23848692827258 37.09422230041189
# Writing to:  LkHa330_HR1620_20121022_0953_M0_div.fits
# SNR: 39.14426515255007 37.89608487844145 32.88209247793653
# Writing to:  LkHa330_HR1620_20121022_0953_M2_div.fits

# %% [markdown]
# ## 20121230, 20121231

# %%
datadir='/Users/csalyk/Dropbox/NIRSPEC_timedomain/data/'
filelist=glob.glob(datadir+'*20121231*.fits')
for i,file in enumerate(filelist):
    filename=(file.split('/'))[-1]
    hdulist=fits.open(file)
#    print(filename,hdulist[0].header['AIRMASS'],hdulist[0].header['FILNAME'],hdulist[0].header['WAVA_POS'])

# %%
#20121230
srcfile='LkHa330_20121230_0431_spec1d1.fits'
stdfile='HR2714_20121231_1330_spec1d1.fits'
#out=divspec(datadir, srcfile, stdfile, dtau=0.0, dpix=-0.3,mode='M0')

srcfile='LkHa330_20121230_0431_spec1d2.fits'
stdfile='HR2714_20121231_1330_spec1d2.fits'
#out=divspec(datadir, srcfile, stdfile, dtau=0.05, dpix=-0.2, mode='M2')

srcfile='LkHa330_20121230_0504_spec1d1.fits'
stdfile='HR1620_20121230_0651_spec1d1.fits'
#out=divspec(datadir, srcfile, stdfile, dtau=0.07, dpix=0.5,mode='M0')

srcfile='LkHa330_20121230_0504_spec1d2.fits'
stdfile='HR1620_20121230_0651_spec1d2.fits'
#out=divspec(datadir, srcfile, stdfile, dtau=0.05, dpix=0.6, mode='M2')

#20121231
srcfile='LkHa330_20121231_0434_spec1d1.fits'
stdfile='HR1620_20121231_0550_spec1d1.fits'
#out=divspec(datadir, srcfile, stdfile, dtau=0.04, dpix=0.2,mode='M0')

srcfile='LkHa330_20121231_0434_spec1d2.fits'
stdfile='HR1620_20121231_0550_spec1d2.fits'
#out=divspec(datadir, srcfile, stdfile, dtau=0.0, dpix=0.2, mode='M2')

srcfile='LkHa330_20121231_0450_spec1d1.fits'
stdfile='HR1620_20121231_0550_spec1d1.fits'
#out=divspec(datadir, srcfile, stdfile, dtau=0.0, dpix=0.2,mode='M0')

srcfile='LkHa330_20121231_0450_spec1d2.fits'
stdfile='HR1620_20121231_0550_spec1d2.fits'
#out=divspec(datadir, srcfile, stdfile, dtau=0.0, dpix=0.2, mode='M2')

srcfile='LkHa330_20121231_0509_spec1d1.fits'
stdfile='HR1620_20121231_0550_spec1d1.fits'
#out=divspec(datadir, srcfile, stdfile, dtau=-0.08, dpix=0.2,mode='M0')

srcfile='LkHa330_20121231_0509_spec1d2.fits'
stdfile='HR1620_20121231_0550_spec1d2.fits'
#out=divspec(datadir, srcfile, stdfile, dtau=-0.08, dpix=0.2, mode='M2')

srcfile='LkHa330_20121231_0525_spec1d1.fits'
stdfile='HR1620_20121231_0550_spec1d1.fits'
#out=divspec(datadir, srcfile, stdfile, dtau=-0.08, dpix=0.3,mode='M0')

srcfile='LkHa330_20121231_0525_spec1d2.fits'
stdfile='HR1620_20121231_0550_spec1d2.fits'
#out=divspec(datadir, srcfile, stdfile, dtau=-0.1, dpix=0.1, mode='M2')
# Out:
# SNR: 54.32279770244326 60.18103573990416 55.30306079683253
# Writing to:  LkHa330_HR1620_20121231_0525_M2_div.fits

# %% [markdown]
# ## 20130101, 20130102, 20130103

# %%
datadir='/Users/csalyk/Dropbox/NIRSPEC_timedomain/data/'
filelist=glob.glob(datadir+'*20130102*.fits')
for i,file in enumerate(filelist):
    filename=(file.split('/'))[-1]
    hdulist=fits.open(file)
#    print(filename,hdulist[0].header['AIRMASS'],hdulist[0].header['FILNAME'],hdulist[0].header['WAVA_POS'])

# %%
#20130101
srcfile='LkHa330_20130101_0436_spec1d1.fits'
stdfile='HR1620_20130101_0540_spec1d1.fits'
#out=divspec(datadir, srcfile, stdfile, dtau=-0.05, dpix=-0.2,mode='M1')

srcfile='LkHa330_20130101_0436_spec1d2.fits'
stdfile='HR1620_20130101_0540_spec1d2.fits'
#out=divspec(datadir, srcfile, stdfile, dtau=-0.05, dpix=-0.2,mode='M3')

srcfile='LkHa330_20130101_0454_spec1d1.fits'
stdfile='HR1620_20130101_0540_spec1d1.fits'
#out=divspec(datadir, srcfile, stdfile, dtau=-0.05, dpix=0.2,mode='M1')

srcfile='LkHa330_20130101_0454_spec1d2.fits'
stdfile='HR1620_20130101_0540_spec1d2.fits'
#out=divspec(datadir, srcfile, stdfile, dtau=-0.05, dpix=0.2,mode='M3')

srcfile='LkHa330_20130101_0509_spec1d1.fits'
stdfile='HR1620_20130101_0646_spec1d1.fits'
#out=divspec(datadir, srcfile, stdfile, dtau=0.03, dpix=0.1,mode='M1')

srcfile='LkHa330_20130101_0509_spec1d2.fits'
stdfile='HR1620_20130101_0646_spec1d2.fits'
#out=divspec(datadir, srcfile, stdfile, dtau=0.03, dpix=0.1,mode='M3')

srcfile='LkHa330_20130101_0525_spec1d1.fits'
stdfile='HR1620_20130101_0646_spec1d1.fits'
#out=divspec(datadir, srcfile, stdfile, dtau=0.0, dpix=0,mode='M1')

srcfile='LkHa330_20130101_0525_spec1d2.fits'
stdfile='HR1620_20130101_0646_spec1d2.fits'
#out=divspec(datadir, srcfile, stdfile, dtau=0.0, dpix=0,mode='M3')

#20130102
srcfile='LkHa330_20130102_0428_spec1d1.fits'
stdfile='HR2714_20130102_1255_spec1d1.fits'
#out=divspec(datadir, srcfile, stdfile, dtau=0.0, dpix=-0.5,mode='M0')

srcfile='LkHa330_20130102_0428_spec1d2.fits'
stdfile='HR2714_20130102_1255_spec1d2.fits'
#out=divspec(datadir, srcfile, stdfile, dtau=0.0, dpix=-0.4,mode='M2')

srcfile='LkHa330_20130102_0453_spec1d1.fits'
stdfile='HR1620_20130102_1109_spec1d1.fits'
#out=divspec(datadir, srcfile, stdfile, dtau=0.0, dpix=0.3,mode='M0')

srcfile='LkHa330_20130102_0453_spec1d2.fits'
stdfile='HR1620_20130102_1109_spec1d2.fits'
#out=divspec(datadir, srcfile, stdfile, dtau=0.0, dpix=0.2,mode='M2')
# Out:
# SNR: 48.355314831193745 44.28105754224585 41.800643379303864
# Writing to:  LkHa330_HR1620_20130102_0453_M2_div.fits

# %% [markdown]
# ## 20130128

# %% [markdown]
# ## 2013060624,2013060625,2013060627,2013060628

# %% [markdown]
# ## 20131019, 20131020

# %%
datadir='/Users/csalyk/Dropbox/NIRSPEC_timedomain/data/'
filelist=glob.glob(datadir+'*20131019*.fits')
for i,file in enumerate(filelist):
    filename=(file.split('/'))[-1]
    hdulist=fits.open(file)
#    print(filename,hdulist[0].header['AIRMASS'],hdulist[0].header['FILNAME'],hdulist[0].header['WAVA_POS'])

# %%
#20131019
srcfile='LkHa330_20131019_1428_spec1d1.fits'
stdfile='HR1620_20131019_1324_spec1d1.fits'
#out=divspec(datadir, srcfile, stdfile, dtau=0.0, dpix=0.,mode='M0')

srcfile='LkHa330_20131019_1428_spec1d2.fits'
stdfile='HR1620_20131019_1324_spec1d2.fits'
out=divspec(datadir, srcfile, stdfile, dtau=-0.05, dpix=-0.2,mode='M2')
# Out:
# SNR: 0.16239274736992748 0.28779202956105127 0.4810742475856072
# Writing to:  LkHa330_HR1620_20131019_1428_M2_div.fits

# %% [markdown]
# ## 20131223, 20131224

# %%
datadir='/Users/csalyk/Dropbox/NIRSPEC_timedomain/data/'
filelist=glob.glob(datadir+'*20131224*.fits')
for i,file in enumerate(filelist):
    filename=(file.split('/'))[-1]
    hdulist=fits.open(file)
#    print(filename,hdulist[0].header['AIRMASS'],hdulist[0].header['FILNAME'],hdulist[0].header['WAVA_POS'])

# %%
#20131223
srcfile='LkHa330_20131223_0454_spec1d1.fits'
stdfile='HR1620_20131223_1241_spec1d1.fits'
#out=divspec(datadir, srcfile, stdfile, dtau=-0.04, dpix=0.,mode='M0')

srcfile='LkHa330_20131223_0454_spec1d2.fits'
stdfile='HR1620_20131223_1241_spec1d2.fits'
#out=divspec(datadir, srcfile, stdfile, dtau=-0.04, dpix=0,mode='M2')

srcfile='LkHa330_20131223_0519_spec1d1.fits'
stdfile='HR1177_20131223_0543_spec1d1.fits'
#out=divspec(datadir, srcfile, stdfile, dtau=-0.05, dpix=0.3,mode='M0')

srcfile='LkHa330_20131223_0519_spec1d2.fits'
stdfile='HR1177_20131223_0543_spec1d2.fits'
#out=divspec(datadir, srcfile, stdfile, dtau=-0.05, dpix=0.3,mode='M2')

#20131224
srcfile='LkHa330_20131224_0434_spec1d1.fits'
stdfile='HR1620_20131224_1213_spec1d1.fits'
#out=divspec(datadir, srcfile, stdfile, dtau=0.05, dpix=0.1,mode='M0')

srcfile='LkHa330_20131224_0434_spec1d2.fits'
stdfile='HR1620_20131224_1213_spec1d2.fits'
#out=divspec(datadir, srcfile, stdfile, dtau=0.05, dpix=0.1,mode='M2')

srcfile='LkHa330_20131224_0507_spec1d1.fits'
stdfile='HR1620_20131224_1213_spec1d1.fits'
#out=divspec(datadir, srcfile, stdfile, dtau=-0.13, dpix=0.4,mode='M0')

srcfile='LkHa330_20131224_0507_spec1d2.fits'
stdfile='HR1620_20131224_1213_spec1d2.fits'
#out=divspec(datadir, srcfile, stdfile, dtau=-0.13, dpix=0.3,mode='M2')
# Out:
# SNR: 85.72221234999787 110.59091885733908 19.95998333624824
# Writing to:  LkHa330_HR1620_20131224_0507_M0_div.fits

# %% [markdown]
# ## 20140906

# %% [markdown]
# ## 20141201

# %% [markdown]
# ## Combine spectra together

# %% [markdown]
# At this point, we want to combine the data from each small set of dates together.  Collect all of the output files below.

# %%
lkha330_20101214_files=['LkHa330_HR383_20101214_0638_M1_div.fits','LkHa330_HR383_20101214_0638_M3_div.fits',
                        'LkHa330_HR383_20101214_0709_M1_div.fits','LkHa330_HR383_20101214_0709_M3_div.fits',
                        'LkHa330_HR383_20101214_0738_M1_div.fits','LkHa330_HR383_20101214_0738_M3_div.fits',
                        'LkHa330_HR383_20101214_0820_M1_div.fits','LkHa330_HR383_20101214_0820_M3_div.fits',
                        'LkHa330_HR936_20101215_0524_M1_div.fits','LkHa330_HR936_20101215_0524_M3_div.fits',
                        'LkHa330_HR1620_20101215_0454_M1_div.fits','LkHa330_HR1620_20101215_0454_M3_div.fits']

lkha330_20121022_files=['LkHa330_HR1620_20121022_0903_M0_div.fits','LkHa330_HR1620_20121022_0903_M2_div.fits',
                       'LkHa330_HR1620_20121022_0953_M0_div.fits','LkHa330_HR1620_20121022_0953_M2_div.fits']

lkha330_20121230_files=['LkHa330_HR1620_20121230_0431_M0_div.fits','LkHa330_HR1620_20121230_0431_M2_div.fits',
                       'LkHa330_HR1620_20121230_0504_M0_div.fits','LkHa330_HR1620_20121230_0504_M2_div.fits',
                       'LkHa330_HR1620_20121231_0434_M0_div.fits','LkHa330_HR1620_20121231_0434_M2_div.fits',
                       'LkHa330_HR1620_20121231_0450_M0_div.fits','LkHa330_HR1620_20121231_0450_M2_div.fits',
                       'LkHa330_HR1620_20121231_0509_M0_div.fits','LkHa330_HR1620_20121231_0509_M2_div.fits',
                       'LkHa330_HR1620_20121231_0525_M0_div.fits','LkHa330_HR1620_20121231_0525_M2_div.fits']

lkha330_20130101_files=['LkHa330_HR1620_20130101_0436_M1_div.fits','LkHa330_HR1620_20130101_0436_M3_div.fits',
                       'LkHa330_HR1620_20130101_0454_M1_div.fits','LkHa330_HR1620_20130101_0454_M3_div.fits',
                       'LkHa330_HR1620_20130101_0509_M1_div.fits','LkHa330_HR1620_20130101_0509_M3_div.fits',
                       'LkHa330_HR1620_20130101_0525_M1_div.fits','LkHa330_HR1620_20130101_0525_M3_div.fits',
                       'LkHa330_HR2714_20130102_0428_M0_div.fits','LkHa330_HR2714_20130102_0428_M2_div.fits',
                       'LkHa330_HR1620_20130102_0453_M0_div.fits','LkHa330_HR1620_20130102_0453_M2_div.fits']

lkha330_20131223_files=['LkHa330_HR1177_20131223_0519_M0_div.fits','LkHa330_HR1177_20131223_0519_M2_div.fits',
                       'LkHa330_HR1620_20131223_0454_M0_div.fits','LkHa330_HR1620_20131223_0454_M2_div.fits',
                       'LkHa330_HR1620_20131224_0434_M0_div.fits','LkHa330_HR1620_20131224_0434_M2_div.fits',
                       'LkHa330_HR1620_20131224_0507_M0_div.fits','LkHa330_HR1620_20131224_0507_M2_div.fits']

# %% [markdown]
# Now use gluespec to combine them.

# %%
(wave,div)=gluespec('/Users/csalyk/Dropbox/NIRSPEC_timedomain/divdata/',lkha330_20101214_files)
(wave,div)=gluespec('/Users/csalyk/Dropbox/NIRSPEC_timedomain/divdata/',lkha330_20121022_files)
(wave,div)=gluespec('/Users/csalyk/Dropbox/NIRSPEC_timedomain/divdata/',lkha330_20121230_files)
(wave,div)=gluespec('/Users/csalyk/Dropbox/NIRSPEC_timedomain/divdata/',lkha330_20130101_files)
(wave,div)=gluespec('/Users/csalyk/Dropbox/NIRSPEC_timedomain/divdata/',lkha330_20131223_files)
# Out:
# Writing to:  LkHa330_20101214_glue.fits
# Writing to:  LkHa330_20121022_glue.fits
# Writing to:  LkHa330_20121230_glue.fits
# Writing to:  LkHa330_20130101_glue.fits
# Writing to:  LkHa330_20131223_glue.fits

# %% [markdown]
# At this point, we can inspect the glued datasets.

# %%
hdulist=fits.open('/Users/csalyk/Dropbox/NIRSPEC_timedomain/gluedata/LkHa330_20101214_glue.fits')
data=hdulist[1].data
fig=plt.figure(figsize=(14,6))
ax1=fig.add_subplot(211)
ax2=fig.add_subplot(212)

ax1.plot(data['wave'],data['div'],linestyle='steps-mid')
ax2.plot(data['wave'],data['std'],linestyle='steps-mid')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-d9a4cb5f1f9a> in <module>
# ----> 1 hdulist=fits.open('/Users/csalyk/Dropbox/NIRSPEC_timedomain/gluedata/LkHa330_20101214_glue.fits')
#       2 data=hdulist[1].data
#       3 fig=plt.figure(figsize=(14,6))
#       4 ax1=fig.add_subplot(211)
#       5 ax2=fig.add_subplot(212)
#
# NameError: name 'fits' is not defined

# %%
hdulist=fits.open('/Users/csalyk/Dropbox/NIRSPEC_timedomain/gluedata/LkHa330_20121022_glue.fits')
data=hdulist[1].data
fig=plt.figure(figsize=(14,6))
ax1=fig.add_subplot(211)
ax2=fig.add_subplot(212)

ax1.plot(data['wave'],data['div'],linestyle='steps-mid')
ax2.plot(data['wave'],data['std'],linestyle='steps-mid')

# %%
hdulist=fits.open('/Users/csalyk/Dropbox/NIRSPEC_timedomain/gluedata/LkHa330_20121230_glue.fits')
data=hdulist[1].data
fig=plt.figure(figsize=(14,6))
ax1=fig.add_subplot(211)
ax2=fig.add_subplot(212)

ax1.plot(data['wave'],data['div'],linestyle='steps-mid')
ax2.plot(data['wave'],data['std'],linestyle='steps-mid')

# %%
hdulist=fits.open('/Users/csalyk/Dropbox/NIRSPEC_timedomain/gluedata/LkHa330_20130101_glue.fits')
data=hdulist[1].data
fig=plt.figure(figsize=(14,6))
ax1=fig.add_subplot(211)
ax2=fig.add_subplot(212)

ax1.plot(data['wave'],data['div'],linestyle='steps-mid')
ax2.plot(data['wave'],data['std'],linestyle='steps-mid')

# %%
hdulist=fits.open('/Users/csalyk/Dropbox/NIRSPEC_timedomain/gluedata/LkHa330_20131223_glue.fits')
data=hdulist[1].data
fig=plt.figure(figsize=(14,6))
ax1=fig.add_subplot(211)
ax2=fig.add_subplot(212)

ax1.plot(data['wave'],data['div'],linestyle='steps-mid')
ax2.plot(data['wave'],data['std'],linestyle='steps-mid')
